# %%
import numpy as np

# %%
import json
with open ('../artifects/kaggle.json', 'r')as file:
 data = json.load (file)

# %%
data
# Out:
# {'username': 'shabrafathima', 'key': 'cb76140c8575ef3c5e7b2cb38040cbae'}

# %%
# !pip install kaggle

# %%
import os
os.environ['KAGGLE_USERNAME']= data['username']
os.environ['KAGGLE_KEY'] = data['key']

# %%
from kaggle.api.kaggle_api_extended import KaggleApi
api=KaggleApi()
api.authenticate()

# %%
api.dataset_download_files('dineshpiyasamara/sentiment-analysis-dataset',path ='../artifects/')
# Out:
# Dataset URL: https://www.kaggle.com/datasets/dineshpiyasamara/sentiment-analysis-dataset

# %%
import zipfile
with zipfile.ZipFile('../artifects/sentiment-analysis-dataset.zip','r') as zip_ref:
   zip_ref.extractall('../artifects')
